# %% [markdown]
# # Sensitivity Scan
#
# Synthetic prototype only: this is an analytic toy sensitivity scan, not a data constraint.

# %%
from viscollapse.scans import lambda_fpaired_scan

lambda_fpaired_scan().round(4)
