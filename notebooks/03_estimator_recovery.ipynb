# %% [markdown]
# # Estimator Recovery
#
# Synthetic prototype only: the samples below are Gaussian draws from toy covariance matrices and are not observational data.

# %%
from viscollapse.constants import SEED_117
from viscollapse.covariance import template_117_mode
from viscollapse.estimator import monte_carlo_recovery

monte_carlo_recovery(template_117_mode(), n_draws=50_000, seed=SEED_117)
