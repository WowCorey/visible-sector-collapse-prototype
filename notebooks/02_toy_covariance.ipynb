# %% [markdown]
# # Toy Covariance Blocks
#
# Synthetic prototype only: these matrices are hand-built toy covariance templates, not real CMB covariance matrices.

# %%
from viscollapse.covariance import template_117_mode, template_summary, toy_covariance_6x6

d6 = toy_covariance_6x6()
d117 = template_117_mode()
template_summary(d6), template_summary(d117)
